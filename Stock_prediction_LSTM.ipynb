# %% [markdown]
# <a href="https://colab.research.google.com/github/dWanderingSoul/Stock-prediction-/blob/main/Stock_prediction_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
import yfinance as yf

# Download Microsoft stock data from start to today
msft_data = yf.download("MSFT", start="1986-03-13", end="2025-02-13")  # Microsoft's IPO was on March 13, 1986

# Save to CSV
msft_data.to_csv("microsoft_stock_data.csv")

# Display first few rows
print(msft_data.head())
# Download Microsoft stock data from start to today
msft_data = yf.download("MSFT", start="1986-03-13", end="2025-02-13")  # Microsoft's IPO was on March 13, 1986

# Save to CSV
msft_data.to_csv("microsoft_stock_data.csv")

# Display first few rows
print(msft_data.head())
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.52)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open      Volume
# Ticker          MSFT      MSFT      MSFT      MSFT        MSFT
# Date
# 1986-03-13  0.059827  0.062498  0.054485  0.054485  1031788800
# 1986-03-14  0.061963  0.063032  0.059827  0.059827   308160000
# 1986-03-17  0.063032  0.063566  0.061963  0.061963   133171200
# 1986-03-18  0.061429  0.063566  0.060895  0.063032    67766400
# 1986-03-19  0.060361  0.061963  0.059827  0.061429    47894400
# Price          Close      High       Low      Open      Volume
# Ticker          MSFT      MSFT      MSFT      MSFT        MSFT
# Date
# 1986-03-13  0.059827  0.062498  0.054485  0.054485  1031788800
# 1986-03-14  0.061963  0.063032  0.059827  0.059827   308160000
# 1986-03-17  0.063032  0.063566  0.061963  0.061963   133171200
# 1986-03-18  0.061429  0.063566  0.060895  0.063032    67766400
# 1986-03-19  0.060361  0.061963  0.059827  0.061429    47894400

# %%
import pandas as pd
df = pd.read_csv('microsoft_stock_data.csv')
df
# Out:
#            Price                 Close                 High  \
# 0         Ticker                  MSFT                 MSFT
# 1           Date                   NaN                  NaN
# 2     1986-03-13  0.059826746582984924  0.06249803328621482
# 3     1986-03-14  0.061963263899087906  0.06303214684418693
# 4     1986-03-17   0.06303218752145767  0.06356632215681537
# ...          ...                   ...                  ...
# 9804  2025-02-06    415.82000732421875   418.20001220703125
# 9805  2025-02-07                409.75    418.6499938964844
# 9806  2025-02-10     412.2200012207031    415.4599914550781
# 9807  2025-02-11    411.44000244140625     412.489990234375
# 9808  2025-02-12     409.0400085449219               410.75
#
#                       Low                 Open      Volume
# 0                    MSFT                 MSFT        MSFT
# 1                     NaN                  NaN         NaN
# 2     0.05448540190449644  0.05448540190449644  1031788800
# 3     0.05982672673645353  0.05982672673645353   308160000
# 4     0.06196330388656394  0.06196330388656394   133171200
# ...                   ...                  ...         ...
# 9804                414.0                414.0    16309800
# 9805    408.1000061035156    416.4800109863281    22886800
# 9806    410.9200134277344    413.7099914550781    20817900
# 9807   409.29998779296875    409.6400146484375    18140600
# 9808    404.3699951171875    407.2099914550781    19099500
#
# [9809 rows x 6 columns]

# %%
df = df [['Price','Close']]
df
# Out:
#            Price                 Close
# 0         Ticker                  MSFT
# 1           Date                   NaN
# 2     1986-03-13  0.059826746582984924
# 3     1986-03-14  0.061963263899087906
# 4     1986-03-17   0.06303218752145767
# ...          ...                   ...
# 9804  2025-02-06    415.82000732421875
# 9805  2025-02-07                409.75
# 9806  2025-02-10     412.2200012207031
# 9807  2025-02-11    411.44000244140625
# 9808  2025-02-12     409.0400085449219
#
# [9809 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv('microsoft_stock_data_modified.csv')
df
# Out:
#             Date       Close        High         Low        Open      Volume
# 0     1986-03-13    0.059827    0.062498    0.054485    0.054485  1031788800
# 1     1986-03-14    0.061963    0.063032    0.059827    0.059827   308160000
# 2     1986-03-17    0.063032    0.063566    0.061963    0.061963   133171200
# 3     1986-03-18    0.061429    0.063566    0.060895    0.063032    67766400
# 4     1986-03-19    0.060361    0.061963    0.059827    0.061429    47894400
# ...          ...         ...         ...         ...         ...         ...
# 9802  2025-02-06  415.820007  418.200012  414.000000  414.000000    16309800
# 9803  2025-02-07  409.750000  418.649994  408.100006  416.480011    22886800
# 9804  2025-02-10  412.220001  415.459992  410.920013  413.709992    20817900
# 9805  2025-02-11  411.440002  412.489990  409.299988  409.640015    18140600
# 9806  2025-02-12  409.040008  410.750000  404.369995  407.209992    19099500
#
# [9807 rows x 6 columns]

# %%
df= df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.059827
# 1     1986-03-14    0.061963
# 2     1986-03-17    0.063032
# 3     1986-03-18    0.061429
# 4     1986-03-19    0.060361
# ...          ...         ...
# 9802  2025-02-06  415.820007
# 9803  2025-02-07  409.750000
# 9804  2025-02-10  412.220001
# 9805  2025-02-11  411.440002
# 9806  2025-02-12  409.040008
#
# [9807 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9802    2025-02-06
# 9803    2025-02-07
# 9804    2025-02-10
# 9805    2025-02-11
# 9806    2025-02-12
# Name: Date, Length: 9807, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year,month, day= int (split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year,month=month,day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.059827
# 1     1986-03-14    0.061963
# 2     1986-03-17    0.063032
# 3     1986-03-18    0.061429
# 4     1986-03-19    0.060361
# ...          ...         ...
# 9802  2025-02-06  415.820007
# 9803  2025-02-07  409.750000
# 9804  2025-02-10  412.220001
# 9805  2025-02-11  411.440002
# 9806  2025-02-12  409.040008
#
# [9807 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-25-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9802   2025-02-06
# 9803   2025-02-07
# 9804   2025-02-10
# 9805   2025-02-11
# 9806   2025-02-12
# Name: Date, Length: 9807, dtype: datetime64[ns]

# %%
df.index= df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.059827
# 1986-03-14    0.061963
# 1986-03-17    0.063032
# 1986-03-18    0.061429
# 1986-03-19    0.060361
# ...                ...
# 2025-02-06  415.820007
# 2025-02-07  409.750000
# 2025-02-10  412.220001
# 2025-02-11  411.440002
# 2025-02-12  409.040008
#
# [9807 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2025-02-12',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  228.637619  230.178040  228.124085  225.101318
# 1    2021-03-26  230.178040  228.124085  225.101318  229.112320
# 2    2021-03-29  228.124085  225.101318  229.112320  227.910980
# 3    2021-03-30  225.101318  229.112320  227.910980  224.626556
# 4    2021-03-31  229.112320  227.910980  224.626556  228.424423
# ..          ...         ...         ...         ...         ...
# 972  2025-02-06  410.920013  412.369995  413.290008  415.820007
# 973  2025-02-07  412.369995  413.290008  415.820007  409.750000
# 974  2025-02-10  413.290008  415.820007  409.750000  412.220001
# 975  2025-02-11  415.820007  409.750000  412.220001  411.440002
# 976  2025-02-12  409.750000  412.220001  411.440002  409.040008
#
# [977 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((977,), (977, 3, 1), (977,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 91786.0938 - mean_absolute_error: 298.3963 - val_loss: 179627.7344 - val_mean_absolute_error: 423.4676
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 89344.7656 - mean_absolute_error: 294.0053 - val_loss: 174681.1094 - val_mean_absolute_error: 417.5857
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 83828.1250 - mean_absolute_error: 284.2246 - val_loss: 157329.0469 - val_mean_absolute_error: 396.2650
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 70499.2969 - mean_absolute_error: 260.0504 - val_loss: 125975.8594 - val_mean_absolute_error: 354.5039
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46900.3789 - mean_absolute_error: 210.1994 - val_loss: 81793.6172 - val_mean_absolute_error: 285.4651
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20850.8340 - mean_absolute_error: 133.8575 - val_loss: 38801.9258 - val_mean_absolute_error: 196.2119
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5754.2471 - mean_absolute_error: 58.1848 - val_loss: 18270.1836 - val_mean_absolute_error: 134.0423
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2805.1296 - mean_absolute_error: 42.8658 - val_loss: 15732.0742 - val_mean_absolute_error: 124.2144
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2786.8140 - mean_absolute_error: 43.8851 - val_loss: 16521.2949 - val_mean_absolute_error: 127.3516
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2596.3000 - mean_absolute_error: 41.7417 - val_loss: 16410.0723 - val_mean_absolute_error: 126.9780
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2123.7034 - mean_absolute_error: 36.4761 - val_loss: 13895.0342 - val_mean_absolute_error: 116.6361
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2099.5203 - mean_absolute_error: 36.5603 - val_loss: 12828.2715 - val_mean_absolute_error: 112.0764
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1814.6161 - mean_absolute_error: 32.9124 - val_loss: 9830.5117 - val_mean_absolute_error: 97.7249
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 965.5524 - mean_absolute_error: 22.4744 - val_loss: 7513.5562 - val_mean_absolute_error: 85.1395
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 582.8748 - mean_absolute_error: 14.7388 - val_loss: 4817.0771 - val_mean_absolute_error: 67.4967
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 321.3835 - mean_absolute_error: 11.1093 - val_loss: 3307.1196 - val_mean_absolute_error: 55.2745
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 173.1087 - mean_absolute_error: 8.1208 - val_loss: 2328.4729 - val_mean_absolute_error: 45.7162
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 105.2843 - mean_absolute_error: 6.7027 - val_loss: 1734.2496 - val_mean_absolute_error: 38.8119
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 92.4541 - mean_absolute_error: 6.4629 - val_loss: 1295.0986 - val_mean_absolute_error: 32.6992
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 85.3973 - mean_absolute_error: 6.9366 - val_loss: 1062.3129 - val_mean_absolute_error: 29.1801
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 63.4235 - mean_absolute_error: 6.0546 - val_loss: 946.4321 - val_mean_absolute_error: 27.5552
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.7412 - mean_absolute_error: 5.2282 - val_loss: 808.0859 - val_mean_absolute_error: 25.0549
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.9313 - mean_absolute_error: 5.0963 - val_loss: 672.0233 - val_mean_absolute_error: 22.2501
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.3049 - mean_absolute_error: 5.3099 - val_loss: 535.2695 - val_mean_absolute_error: 18.6508
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.9813 - mean_absolute_error: 5.4250 - val_loss: 588.1340 - val_mean_absolute_error: 20.9396
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 41.0379 - mean_absolute_error: 4.9285 - val_loss: 523.2910 - val_mean_absolute_error: 19.4370
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.7159 - mean_absolute_error: 4.7278 - val_loss: 499.3490 - val_mean_absolute_error: 19.0714
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.0221 - mean_absolute_error: 4.5634 - val_loss: 385.6512 - val_mean_absolute_error: 15.3630
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.0809 - mean_absolute_error: 4.5405 - val_loss: 438.0020 - val_mean_absolute_error: 17.6570
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 36.8225 - mean_absolute_error: 4.7168 - val_loss: 375.0105 - val_mean_absolute_error: 15.6083
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.4497 - mean_absolute_error: 4.4463 - val_loss: 317.4179 - val_mean_absolute_error: 13.6725
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.3858 - mean_absolute_error: 4.6496 - val_loss: 296.7779 - val_mean_absolute_error: 13.0316
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.1624 - mean_absolute_error: 4.6359 - val_loss: 297.4985 - val_mean_absolute_error: 13.2698
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.2901 - mean_absolute_error: 4.6962 - val_loss: 337.9223 - val_mean_absolute_error: 15.1050
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.2003 - mean_absolute_error: 4.4654 - val_loss: 265.8812 - val_mean_absolute_error: 12.2699
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.0059 - mean_absolute_error: 4.4354 - val_loss: 227.2572 - val_mean_absolute_error: 11.2040
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.6287 - mean_absolute_error: 4.5900 - val_loss: 255.1142 - val_mean_absolute_error: 12.1216
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.1371 - mean_absolute_error: 4.2088 - val_loss: 262.4919 - val_mean_absolute_error: 12.6374
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.0174 - mean_absolute_error: 4.0868 - val_loss: 244.2602 - val_mean_absolute_error: 11.9318
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.2302 - mean_absolute_error: 4.2369 - val_loss: 233.1850 - val_mean_absolute_error: 11.6242
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.4061 - mean_absolute_error: 4.4712 - val_loss: 308.1038 - val_mean_absolute_error: 14.7702
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.7996 - mean_absolute_error: 4.8826 - val_loss: 260.9287 - val_mean_absolute_error: 12.9518
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.7993 - mean_absolute_error: 3.9298 - val_loss: 237.0362 - val_mean_absolute_error: 11.9762
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.1328 - mean_absolute_error: 4.6249 - val_loss: 215.0984 - val_mean_absolute_error: 11.0547
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.4771 - mean_absolute_error: 4.3297 - val_loss: 240.0226 - val_mean_absolute_error: 12.2735
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.8226 - mean_absolute_error: 4.3878 - val_loss: 194.6232 - val_mean_absolute_error: 10.3909
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.2816 - mean_absolute_error: 4.4698 - val_loss: 213.6796 - val_mean_absolute_error: 11.2371
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.2140 - mean_absolute_error: 4.1742 - val_loss: 255.3746 - val_mean_absolute_error: 13.1520
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.6267 - mean_absolute_error: 4.6032 - val_loss: 229.2519 - val_mean_absolute_error: 12.1303
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.0196 - mean_absolute_error: 4.1837 - val_loss: 238.9053 - val_mean_absolute_error: 12.5518
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 36.7981 - mean_absolute_error: 4.8240 - val_loss: 201.4542 - val_mean_absolute_error: 10.8358
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28.5353 - mean_absolute_error: 4.2164 - val_loss: 162.5621 - val_mean_absolute_error: 9.5429
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.1671 - mean_absolute_error: 4.4225 - val_loss: 213.4736 - val_mean_absolute_error: 11.5045
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.2968 - mean_absolute_error: 4.5133 - val_loss: 278.5704 - val_mean_absolute_error: 14.3117
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 34.1816 - mean_absolute_error: 4.6035 - val_loss: 272.0189 - val_mean_absolute_error: 14.1138
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 29.6130 - mean_absolute_error: 4.3062 - val_loss: 194.7492 - val_mean_absolute_error: 10.7665
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.0145 - mean_absolute_error: 4.2550 - val_loss: 234.8077 - val_mean_absolute_error: 12.6728
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.3147 - mean_absolute_error: 4.1643 - val_loss: 346.8620 - val_mean_absolute_error: 16.7781
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.9640 - mean_absolute_error: 5.0814 - val_loss: 226.9850 - val_mean_absolute_error: 12.2873
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.4481 - mean_absolute_error: 4.3068 - val_loss: 180.7548 - val_mean_absolute_error: 10.1707
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.9302 - mean_absolute_error: 4.0268 - val_loss: 191.7603 - val_mean_absolute_error: 10.7355
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.6858 - mean_absolute_error: 4.1338 - val_loss: 169.4297 - val_mean_absolute_error: 9.7849
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 52.0450 - mean_absolute_error: 5.7495 - val_loss: 218.1004 - val_mean_absolute_error: 11.7672
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.9864 - mean_absolute_error: 4.0465 - val_loss: 213.3864 - val_mean_absolute_error: 11.5982
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.8647 - mean_absolute_error: 4.0258 - val_loss: 247.9416 - val_mean_absolute_error: 13.2342
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.3982 - mean_absolute_error: 4.9599 - val_loss: 184.4671 - val_mean_absolute_error: 10.3785
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.0948 - mean_absolute_error: 4.1138 - val_loss: 158.4368 - val_mean_absolute_error: 9.3497
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.3113 - mean_absolute_error: 3.9749 - val_loss: 154.4342 - val_mean_absolute_error: 9.2287
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.8696 - mean_absolute_error: 4.1055 - val_loss: 173.8803 - val_mean_absolute_error: 10.0728
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.8772 - mean_absolute_error: 4.2017 - val_loss: 159.2212 - val_mean_absolute_error: 9.4224
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.0834 - mean_absolute_error: 4.2082 - val_loss: 157.2816 - val_mean_absolute_error: 9.4031
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.1118 - mean_absolute_error: 4.5480 - val_loss: 201.3795 - val_mean_absolute_error: 11.3780
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.9849 - mean_absolute_error: 3.9987 - val_loss: 229.8427 - val_mean_absolute_error: 12.7138
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 36.6158 - mean_absolute_error: 4.8906 - val_loss: 139.3883 - val_mean_absolute_error: 8.8890
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.8952 - mean_absolute_error: 4.1603 - val_loss: 141.7516 - val_mean_absolute_error: 8.9272
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.8238 - mean_absolute_error: 4.2077 - val_loss: 143.3703 - val_mean_absolute_error: 8.9113
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.4120 - mean_absolute_error: 4.5600 - val_loss: 153.6030 - val_mean_absolute_error: 9.2242
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.6719 - mean_absolute_error: 4.1139 - val_loss: 147.0159 - val_mean_absolute_error: 9.0006
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.1457 - mean_absolute_error: 4.1176 - val_loss: 198.9237 - val_mean_absolute_error: 11.4439
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.8687 - mean_absolute_error: 4.3369 - val_loss: 140.7300 - val_mean_absolute_error: 8.8566
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.6556 - mean_absolute_error: 4.7255 - val_loss: 137.1573 - val_mean_absolute_error: 8.7931
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.9507 - mean_absolute_error: 4.3901 - val_loss: 148.9055 - val_mean_absolute_error: 9.0463
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.4101 - mean_absolute_error: 3.8931 - val_loss: 148.3639 - val_mean_absolute_error: 9.0363
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.3012 - mean_absolute_error: 4.0120 - val_loss: 195.1291 - val_mean_absolute_error: 11.2334
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.1459 - mean_absolute_error: 4.2680 - val_loss: 295.1430 - val_mean_absolute_error: 15.1478
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 38.8444 - mean_absolute_error: 4.9450 - val_loss: 160.2208 - val_mean_absolute_error: 9.4755
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.9679 - mean_absolute_error: 3.6658 - val_loss: 146.5090 - val_mean_absolute_error: 8.9816
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.5565 - mean_absolute_error: 3.9351 - val_loss: 145.8058 - val_mean_absolute_error: 8.9577
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.4897 - mean_absolute_error: 4.0841 - val_loss: 159.1702 - val_mean_absolute_error: 9.5694
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.4698 - mean_absolute_error: 3.8624 - val_loss: 173.1857 - val_mean_absolute_error: 10.2584
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.4056 - mean_absolute_error: 3.6716 - val_loss: 198.8293 - val_mean_absolute_error: 11.6561
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.6356 - mean_absolute_error: 4.1172 - val_loss: 203.7751 - val_mean_absolute_error: 11.9386
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.1593 - mean_absolute_error: 4.2268 - val_loss: 317.9489 - val_mean_absolute_error: 16.1545
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 37.2163 - mean_absolute_error: 4.6880 - val_loss: 231.3930 - val_mean_absolute_error: 12.9093
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 28.9963 - mean_absolute_error: 4.2313 - val_loss: 167.3793 - val_mean_absolute_error: 9.8940
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 26.2373 - mean_absolute_error: 3.9808 - val_loss: 177.7089 - val_mean_absolute_error: 10.3767
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 29.2632 - mean_absolute_error: 4.2569 - val_loss: 196.2028 - val_mean_absolute_error: 11.3364
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 34.2019 - mean_absolute_error: 4.6456 - val_loss: 169.5696 - val_mean_absolute_error: 10.1759
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.4016 - mean_absolute_error: 4.0986 - val_loss: 157.1003 - val_mean_absolute_error: 9.6344
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.9078 - mean_absolute_error: 4.0645 - val_loss: 164.4952 - val_mean_absolute_error: 10.0047

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-63cbe8233b53> in <cell line: 0>()
#       3
#       4 # Assuming y_test are actual stock prices and y_pred are predicted values from LSTM
# ----> 5 mae = mean_absolute_error(y_test, y_pred)
#       6 rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#       7 mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100  # MAPE calculation
#
# NameError: name 'y_pred' is not defined
